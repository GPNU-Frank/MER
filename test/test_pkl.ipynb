# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
data_path = 'G:\\vscode_workspace\\MER\\dataset\\CASME2_224_15frames.pickle'
data_path = 'G:\\vscode_workspace\\MER\\dataset\\CASME2_BGR_224_15frames.pickle'

if not os.path.exists(data_path):
    print('file {0} not exists'.format(data_path))
    exit()
with open(data_path, 'rb') as f:
    data = pickle.load(f)

# %%
print(data[0].keys())
img = data[0]['train_img'][0][8]
print(img.shape)
label = data[0]['train_label'][0]
_, axs = plt.subplots(1, 15)
for ax, img in zip(axs, data[0]['train_img'][20]):
    ax.imshow(img)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
print(label)
# plt.gray()
# plt.imshow(img)
plt.show()
# Out:
# dict_keys(['train_img', 'train_label', 'test_img', 'test_label'])
# (244, 224, 3)
# 2
